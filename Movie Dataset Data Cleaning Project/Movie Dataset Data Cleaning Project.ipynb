# %% [markdown]
# ## Movie Dataset Data Cleaning Project

# %%
# For Basic Operations
import numpy as np
import pandas as pd

# for Datetime Manipulation
import datetime

# For Data Visualizations
import seaborn as sns
import matplotlib.pyplot as plt

# for Interactive Analysis
from ipywidgets import interact

# %%
import warnings
from warnings import filterwarnings
filterwarnings("ignore")

# %%
# lets import the Dataset
data = pd.read_csv('movies.csv')

# lets check the shape of the dataset
data.shape
# Out:
# (9125, 3)

# %%
# lets check the head of the dataset
data.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# lets also check the ratings dataset
rating = pd.read_csv('ratings.csv')

# lets check the shape also
rating.shape
# Out:
# (100836, 4)

# %%
# lets check the head of the rating data
rating.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# As we are going to Perform the Content Based Filtering
# lets merge the rating data with the movie data
data = pd.merge(data, rating, on = 'movieId', how = 'inner')

# lets check the shape of the Merged Dataset
data.shape
# Out:
# (96811, 6)

# %%
# Lets check the Head of the Merged Dataset
data.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
# As we do not Require the MovieId, UserId and Timestamp lets remove them
data = data.drop(['movieId', 'userId', 'timestamp'], axis = 1)

# lets check the head of the Final Dataset
data.head()
# Out:
#               title                                       genres  rating
# 0  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy     4.0
# 1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy     4.0
# 2  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy     4.5
# 3  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy     2.5
# 4  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy     4.5

# %%
# Now, We Have to Groupby the Dataset Based on the Movie Title

data = pd.pivot_table(data, index = ['title','genres'], aggfunc = 'mean')
data.reset_index(level=['title','genres'], inplace = True)
data.head()
# Out:
#                                      title  \
# 0  'Hellboy': The Seeds of Creation (2004)
# 1                   'Round Midnight (1986)
# 2                      'Salem's Lot (2004)
# 3                'Til There Was You (1997)
# 4                       'burbs, The (1989)
#
#                                         genres    rating
# 0  Action|Adventure|Comedy|Documentary|Fantasy  4.000000
# 1                                Drama|Musical  3.500000
# 2                Drama|Horror|Mystery|Thriller  5.000000
# 3                                Drama|Romance  4.000000
# 4                                       Comedy  3.176471

# %%
# lets check the Distribution of Ratings across the Movies

plt.rcParams['figure.figsize'] = (8, 3)      #used to change the default parameters of the plot's figure.
plt.style.use('fivethirtyeight')             #Uses a predefined style, which tries to replicate the styles from FiveThirtyEight.com.
plt.style.use('fivethirtyeight')
sns.distplot(data['rating'], color = 'black')
plt.title('Distribution of Ratings')
plt.show()

# %%
# Lets Extract Year of Release from the Movie Title
data['y'] = data['title'].str.split(' ')
data['year'] = data['y'].apply(lambda x: x[-1])

# lets drop the unnecessary 'y' column from the dataset
data = data.drop(['y'], axis = 1)

# lets remove the Opening and Closing Brackets from the String
data['year'] = data['year'].str.strip(')')
data['year'] = data['year'].str.strip('(')

# lets check the Values After Extraction
pd.set_option('max_rows', 110)
data['year'].value_counts()
# Out:
# 2002    244
# 1996    240
# 1995    228
# 2001    227
# 2000    225
# 1998    225
# 1999    221
# 1997    217
# 2004    206
# 2006    204
# 1994    198
# 2003    197
# 2005    195
# 2007    195
# 2009    190
# 2008    189
# 2011    180
# 2010    179
# 2014    170
# 1993    166
# 2013    166
# 2012    160
# 2015    148
# 1988    133
# 1992    127
# 1987    123
# 1990    117
# 1986    115
# 1989    115
# 1991    111
# 1985    105
# 1984     77
# 1982     71
# 1983     67
# 1981     64
# 1980     63
# 2016     52
# 1979     48
# 1977     47
# 1978     46
# 1973     41
# 1974     39
# 1971     33
# 1955     32
# 1962     32
# 1965     32
# 1975     32
# 1959     32
# 1976     31
# 1964     31
# 1960     30
# 1966     30
# 1972     30
# 1963     29
# 1968     28
# 1967     28
# 1957     26
# 1953     26
# 1961     25
# 1958     24
# 1970     23
# 1969     22
# 1956     22
# 1954     20
# 1939     20
# 1942     20
# 1947     17
# 1940     17
# 1950     16
# 1948     16
# 1946     16
# 1951     16
# 1949     15
# 1941     15
# 1937     14
# 1945     13
# 1952     13
# 1944     12
# 1936     11
# 1938     10
# 1931      9
# 1933      8
# 1932      8
# 1934      7
# 1943      6
# 1935      6
# 1929      4
# 1928      4
# 1925      4
# 1927      4
# 1924      4
# 1930      3
# 1926      3
# 1916      2
# 1923      2
# 1902      1
# 1917      1
# 1920      1
# 1915      1
# 1922      1
# Road      1
# 1921      1
#           1
# Name: year, dtype: int64

# %%
# There are some Dirty Values, Let's Clean them
data['year'] = data['year'].replace(('2007-','Despot','Things', '1975-1979','Road', ''),
                                   ('2007','2016','2016','1979','2002','1996'))

# lets convert the year column into Integer data type
data['year'] = data['year'].astype(int)

# lets check the head of the dataset again
data.head()
# Out:
#                                      title  \
# 0  'Hellboy': The Seeds of Creation (2004)
# 1                   'Round Midnight (1986)
# 2                      'Salem's Lot (2004)
# 3                'Til There Was You (1997)
# 4                       'burbs, The (1989)
#
#                                         genres    rating  year
# 0  Action|Adventure|Comedy|Documentary|Fantasy  4.000000  2004
# 1                                Drama|Musical  3.500000  1986
# 2                Drama|Horror|Mystery|Thriller  5.000000  2004
# 3                                Drama|Romance  4.000000  1997
# 4                                       Comedy  3.176471  1989

# %%
# lets remove the Year from the Movie Titles
data['title'] = data['title'].str.split(' ')
data['title'] = data['title'].apply(lambda x: ' '.join(x[:-1]))

# lets check the head of the dataset again
data.head()
# Out:
#                               title  \
# 0  'Hellboy': The Seeds of Creation
# 1                   'Round Midnight
# 2                      'Salem's Lot
# 3                'Til There Was You
# 4                       'burbs, The
#
#                                         genres    rating  year
# 0  Action|Adventure|Comedy|Documentary|Fantasy  4.000000  2004
# 1                                Drama|Musical  3.500000  1986
# 2                Drama|Horror|Mystery|Thriller  5.000000  2004
# 3                                Drama|Romance  4.000000  1997
# 4                                       Comedy  3.176471  1989

# %%
data.head(100)
# Out:
#                                                 title  \
# 0                    'Hellboy': The Seeds of Creation
# 1                                     'Round Midnight
# 2                                        'Salem's Lot
# 3                                  'Til There Was You
# 4                                         'burbs, The
# 5                                       'night Mother
# 6                                (500) Days of Summer
# 7                             *batteries not included
# 8                              ...And Justice for All
# 9                                          1-900 (06)
# 10                                                 10
# 11                                10 Cloverfield Lane
# 12                                   10 Items or Less
# 13                         10 Things I Hate About You
# 14                                           10 Years
# 15                                          10,000 BC
# 16                                          100 Girls
# 17                                     101 Dalmatians
# 18    101 Dalmatians (One Hundred and One Dalmatians)
# 19                      101 Reykjavik (101 Reykjavík)
# 20                                     102 Dalmatians
# 21                                  10th Kingdom, The
# 22                            11'09"01 - September 11
# 23                                              11:14
# 24                                       12 Angry Men
# 25                                       12 Angry Men
# 26                                   12 Years a Slave
# 27                                          127 Hours
# 28                13 Assassins (Jûsan-nin no shikaku)
# 29                                          13 Ghosts
# 30                                     13 Going on 30
# 31                                         13 Tzameti
# 32                                  13th Warrior, The
# 33                                               1408
# 34                                         15 Minutes
# 35                                          16 Blocks
# 36                                           17 Again
# 37                                          18 Again!
# 38                              187 (One Eight Seven)
# 39                                               1941
# 40                        1984 (Nineteen Eighty-Four)
# 41                                 2 Days in New York
# 42                               2 Days in the Valley
# 43     2 Fast 2 Furious (Fast and the Furious 2, The)
# 44                                             2 Guns
# 45                                           20 Dates
# 46    20 Feet from Stardom (Twenty Feet from Stardom)
# 47                       20,000 Leagues Under the Sea
# 48                       20,000 Leagues Under the Sea
# 49                                     200 Cigarettes
# 50                              2001: A Space Odyssey
# 51                     2010: The Year We Make Contact
# 52                                               2012
# 53                                               2046
# 54                                                 21
# 55                                           21 Grams
# 56                                     21 Jump Street
# 57                                              21 Up
# 58                                     22 Jump Street
# 59                               24 Hour Party People
# 60                                          25th Hour
# 61                                         27 Dresses
# 62                                            28 Days
# 63                                      28 Days Later
# 64                                              28 Up
# 65                                     28 Weeks Later
# 66     3 Extremes (Three... Extremes) (Saam gaang yi)
# 67                                           3 Idiots
# 68                                           3 Ninjas
# 69                                 3 Ninjas Kick Back
# 70                                3 Ninjas Knuckle Up
# 71               3 Ninjas: High Noon On Mega Mountain
# 72                              3 Women (Three Women)
# 73                                   3-Iron (Bin-jip)
# 74                                   30 Days of Night
# 75                                 30 Minutes or Less
# 76                                                300
# 77                            3000 Miles to Graceland
# 78                             300: Rise of an Empire
# 79                                              35 Up
# 80                                      39 Steps, The
# 81                                       3:10 to Yuma
# 82                                       3:10 to Yuma
# 83                                     4 Little Girls
# 84  4 Months, 3 Weeks and 2 Days (4 luni, 3 saptam...
# 85                              40 Days and 40 Nights
# 86                            40-Year-Old Virgin, The
# 87            400 Blows, The (Les quatre cents coups)
# 88                                                 42
# 89                                              42 Up
# 90                                        42nd Street
# 91                                           47 Ronin
# 92                                            48 Hrs.
# 93                                              49 Up
# 94  5 Centimeters per Second (Byôsoku 5 senchimêtoru)
# 95                        5,000 Fingers of Dr. T, The
# 96                                     50 First Dates
# 97                                              50/50
# 98                                         52 Pick-Up
# 99                                                 54
#
#                                          genres    rating  year
# 0   Action|Adventure|Comedy|Documentary|Fantasy  4.000000  2004
# 1                                 Drama|Musical  3.500000  1986
# 2                 Drama|Horror|Mystery|Thriller  5.000000  2004
# 3                                 Drama|Romance  4.000000  1997
# 4                                        Comedy  3.176471  1989
# 5                                         Drama  3.000000  1986
# 6                          Comedy|Drama|Romance  3.666667  2009
# 7                Children|Comedy|Fantasy|Sci-Fi  3.285714  1987
# 8                                Drama|Thriller  3.166667  1979
# 9                                 Drama|Romance  4.000000  1994
# 10                               Comedy|Romance  3.375000  1979
# 11                                     Thriller  3.678571  2016
# 12                         Comedy|Drama|Romance  2.666667  2006
# 13                               Comedy|Romance  3.527778  1999
# 14                         Comedy|Drama|Romance  3.500000  2011
# 15                   Adventure|Romance|Thriller  2.705882  2008
# 16                               Comedy|Romance  3.250000  2000
# 17                    Adventure|Children|Comedy  3.074468  1996
# 18                 Adventure|Animation|Children  3.431818  1961
# 19                         Comedy|Drama|Romance  3.500000  2000
# 20                              Children|Comedy  2.777778  2000
# 21                     Adventure|Comedy|Fantasy  2.750000  2000
# 22                                        Drama  4.000000  2002
# 23          Comedy|Crime|Drama|Mystery|Thriller  3.750000  2003
# 24                                        Drama  4.149123  1957
# 25                                  Crime|Drama  5.000000  1997
# 26                                        Drama  3.625000  2013
# 27                     Adventure|Drama|Thriller  3.833333  2010
# 28                                       Action  4.000000  2010
# 29                                       Horror  3.125000  1960
# 30                       Comedy|Fantasy|Romance  3.190476  2004
# 31                           Film-Noir|Thriller  4.500000  2005
# 32                     Action|Adventure|Fantasy  2.903846  1999
# 33                        Drama|Horror|Thriller  3.160000  2007
# 34                                     Thriller  3.000000  2001
# 35                               Crime|Thriller  3.000000  2006
# 36                                 Comedy|Drama  3.550000  2009
# 37                               Comedy|Fantasy  1.500000  1988
# 38                               Drama|Thriller  2.666667  1997
# 39                                   Comedy|War  2.666667  1979
# 40                                 Drama|Sci-Fi  3.714286  1984
# 41                                       Comedy  2.500000  2012
# 42                              Crime|Film-Noir  3.041667  1996
# 43                        Action|Crime|Thriller  2.605263  2003
# 44                          Action|Comedy|Crime  4.000000  2013
# 45                               Comedy|Romance  3.000000  1998
# 46                                  Documentary  4.250000  2013
# 47                      Action|Adventure|Sci-Fi  3.750000  1916
# 48                       Adventure|Drama|Sci-Fi  3.470588  1954
# 49                                 Comedy|Drama  3.166667  1999
# 50                       Adventure|Drama|Sci-Fi  3.894495  1968
# 51                                       Sci-Fi  3.588235  1984
# 52                 Action|Drama|Sci-Fi|Thriller  2.619048  2009
# 53                 Drama|Fantasy|Romance|Sci-Fi  4.071429  2004
# 54                 Crime|Drama|Romance|Thriller  3.750000  2008
# 55         Crime|Drama|Mystery|Romance|Thriller  3.300000  2003
# 56                          Action|Comedy|Crime  3.865385  2012
# 57                                  Documentary  4.000000  1977
# 58                          Action|Comedy|Crime  3.684211  2014
# 59                         Comedy|Drama|Musical  3.571429  2002
# 60                                  Crime|Drama  3.840909  2002
# 61                               Comedy|Romance  3.300000  2008
# 62                                        Drama  3.300000  2000
# 63                         Action|Horror|Sci-Fi  3.974138  2002
# 64                                  Documentary  4.000000  1985
# 65                       Horror|Sci-Fi|Thriller  3.595238  2007
# 66                                       Horror  3.333333  2004
# 67                         Comedy|Drama|Romance  4.750000  2009
# 68                       Action|Children|Comedy  2.083333  1992
# 69                       Action|Children|Comedy  1.250000  1994
# 70                              Action|Children  0.500000  1995
# 71                       Action|Children|Comedy  4.000000  1998
# 72                                        Drama  4.166667  1977
# 73                                Drama|Romance  4.500000  2004
# 74                              Horror|Thriller  3.181818  2007
# 75                          Action|Comedy|Crime  2.666667  2011
# 76                      Action|Fantasy|War|IMAX  3.681250  2007
# 77                              Action|Thriller  2.714286  2001
# 78                        Action|Drama|War|IMAX  2.125000  2014
# 79                                  Documentary  4.000000  1991
# 80                       Drama|Mystery|Thriller  4.045455  1935
# 81      Action|Adventure|Drama|Thriller|Western  4.000000  1957
# 82                   Action|Crime|Drama|Western  4.060000  2007
# 83                                  Documentary  4.250000  1997
# 84                                        Drama  4.000000  2007
# 85                               Comedy|Romance  3.000000  2002
# 86                               Comedy|Romance  3.547297  2005
# 87                                  Crime|Drama  4.000000  1959
# 88                                        Drama  4.000000  2013
# 89                                  Documentary  4.000000  1998
# 90                        Drama|Musical|Romance  4.000000  1933
# 91                     Action|Adventure|Fantasy  2.642857  2013
# 92                    Action|Comedy|Crime|Drama  3.590909  1982
# 93                                  Documentary  4.000000  2005
# 94                      Animation|Drama|Romance  3.500000  2007
# 95                     Children|Fantasy|Musical  4.000000  1953
# 96                               Comedy|Romance  3.553191  2004
# 97                                 Comedy|Drama  3.631579  2011
# 98                      Action|Mystery|Thriller  3.666667  1986
# 99                                        Drama  2.000000  1998
